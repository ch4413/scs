# %%
import pandas as pd

# %%
aa = pd.read_csv('../data/SCS alerts Nov_with_asset_code.csv')

# %%
# Out:
#         Unnamed: 0  Number                                              Alert  \
# 0                0  141254     C17: C1701STA254 254B12 occupancy sensor fault
# 1                1  138183     C17: C1701STA012 012B13 occupancy sensor fault
# 2                2  122518     C15: C1502STA034 034B12 occupancy sensor fault
# 3                3  444609  SCS M09: single module 1 emergency stop unit  ...
# 4                4  139815     C17: C1701STA112 112B13 occupancy sensor fault
# ...            ...     ...                                                ...
# 174085      174085  439314  SCS228: sto: lifter occupation wrong in auto-m...
# 174086      174086  439314  SCS228: sto: lifter occupation wrong in auto-m...
# 174087      174087  439314  SCS228: sto: lifter occupation wrong in auto-m...
# 174088      174088  439308  SCS228: sto: locking device timeout close X:45...
# 174089      174089  439308  SCS228: sto: locking device timeout close X:45...
#
# ...
